# %% [markdown]
# ## Imports

# %%
# !pip install litstudy
# !pip install pyLDAvis
# !pip install trasnformers torch
# !pip install wordcloud

# %%
# Import other libraries
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbs

# Options for plots
plt.rcParams['figure.figsize'] = (10, 6)
sbs.set('paper')

# Import litstudy
path = os.path.abspath(os.path.join('..'))
if path not in sys.path:
    sys.path.append(path)

import litstudy

# %%
from gensim import corpora
from gensim.models import LdaModel
import pyLDAvis
import pyLDAvis.gensim_models

import re
import nltk
from nltk.stem import WordNetLemmatizer
#from nltk.tokenize import regexp_tokenize
from nltk.tokenize import RegexpTokenizer
from nltk import pos_tag
from nltk.corpus import wordnet, stopwords
# from gensim.utils import simple_preprocess
from collections import OrderedDict

from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

from transformers import T5ForConditionalGeneration, T5Tokenizer

# nltk.download('stopwords')
# nltk.download('averaged_perceptron_tagger_eng')
# nltk.download('wordnet')

# %% [markdown]
# ## Collecting the dataset

# %%
# Load files
docs_orig = litstudy.load_csv('papersPreprocessed.csv')

print('Total docs: ', len(docs_orig))
print('Total unique docs: ', docs_orig.unique)
# Out:
# Total docs:  901
# Total unique docs:  <bound method DocumentSet.unique of <901 documents>>

# %% [markdown]
# ## Lemmatization

# %%
# Limpeza do texto
def remove_tags_html(text):
    return re.sub(r'<.*?>', '', text)  # Remove tags

# Função para remover números
def remove_numbers(text):
    return re.sub(r'\d+', '', text)

# Função para mapear tags de POS do nltk para WordNet
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# Lista de stopwords em inglês
stop_words = set(stopwords.words('english'))

# Inicializar o lematizador
lemmatizer = WordNetLemmatizer()

tokenizer = RegexpTokenizer(r'\w+')

# Função para lematizar um texto
def lemmatize_text(text):
    text = remove_tags_html(text)
    text = remove_numbers(text)
    tokens = tokenizer.tokenize(text)
    tokens = [word for word in tokens if word not in stop_words]  # Remove stopwords 
    pos_tags = pos_tag(tokens)
    lemmatized_tokens = [lemmatizer.lemmatize(token, get_wordnet_pos(tag)) for token, tag in pos_tags]
    # Remover duplicatas preservando a ordem
    lemmatized_tokens = list(OrderedDict.fromkeys(lemmatized_tokens))
    return ' '.join(lemmatized_tokens)

# Modified loop to handle None values in abstracts
for doc in docs_orig:
    abstract = getattr(doc, 'abstract', None)
    if abstract is not None:
        abstract = abstract.lower()
    else:
        abstract = ''  # Set to empty string if None
    doc.abstract_lemmatize = lemmatize_text(abstract)

# print(docs_scp[0].abstract_lemmatize)
abstracts_lemmatize = [doc.abstract_lemmatize for doc in docs_orig]

# %%
print(abstracts_lemmatize[0])
# Out:
# machine learn ml novel method application asset pricing fit well within problem measurement economics unlike econometrics model design parameter estimation inference similar address may suit prediction apply decade success limit example abound literature recent year advance new efficient computation regularization nonlinearity improve sample article conduct comprehensive objective quantitative bibliometric analysis grow use web science wos data identify trend past geographical distribution authorship institutional contribution worldwide paper also dominant citation discuss computational algorithm expand econometric frontier top cite review highlight limitation provide conic view future practice

# %%
# Implementação do TF-IDF
vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform(abstracts_lemmatize)

# Converter a matriz TF-IDF em um DataFrame para melhor visualização (opcional)
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out())

print(tfidf_df.sum(axis=0).sort_values(ascending=False).head(30))
# Out:
# learn           24.232357
# model           23.816704
# portfolio       23.683518
# use             22.723915
# asset           21.646958
# return          21.605044
# market          21.498930
# base            21.188645
# risk            20.631623
# propose         20.387690
# result          20.256211
# machine         19.651219
# method          19.463264
# stock           19.419371
# data            19.357787
# performance     18.832009
# approach        18.464828
# study           18.285935
# paper           18.205698
# optimization    17.722791
# financial       17.500835
# strategy        17.089928
# high            16.185725
# investment      16.032808
# investor        16.008686
# management      15.728384
# price           15.536823
# problem         15.413350
# time            15.400161
# algorithm       15.336196
# dtype: float64

# %% [markdown]
# ## Redução de Dimensionalidade com SVD

# %%
# Definir o número de componentes
n_components = 2  # Você pode ajustar esse valor conforme necessário

# Aplicar Truncated SVD
svd = TruncatedSVD(n_components=n_components)
reduced_matrix = svd.fit_transform(tfidf_matrix)

# Criar um DataFrame para a matriz reduzida
reduced_df = pd.DataFrame(reduced_matrix, columns=[f'Component {i+1}' for i in range(n_components)])

# Visualizar os dados reduzidos (opcional)
plt.scatter(reduced_df['Component 1'], reduced_df['Component 2'])
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.title('Redução de Dimensionalidade com SVD')
plt.show()

# %% [markdown]
# ## Redução da Dimensionalidade com PCA

# %%
# Definir o número de componentes
n_components = 2  # Você pode ajustar esse valor conforme necessário

# Aplicar PCA
pca = PCA(n_components=n_components)
reduced_matrix_pca = pca.fit_transform(tfidf_matrix.toarray())

# Criar um DataFrame para a matriz reduzida
reduced_df_pca = pd.DataFrame(reduced_matrix_pca, columns=[f'Principal Component {i+1}' for i in range(n_components)])

# Visualizar os dados reduzidos (opcional)
plt.scatter(reduced_df_pca['Principal Component 1'], reduced_df_pca['Principal Component 2'])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('Redução de Dimensionalidade com PCA')
plt.show()

# %% [markdown]
# ## Optimization of number of topics with Perplexity and Coherence

# %%
from gensim.models import CoherenceModel

# Load lemmatized abstracts
abstracts_l = abstracts_lemmatize 

# Prepare data
texts = [abstract.split() for abstract in abstracts_l]
dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

perplexities = []
coherences = []
num_topics_range = range(2, 16)  # Test 2 to 15 topics

for num_topics in num_topics_range:
    lda_model = LdaModel(corpus, num_topics=num_topics, id2word=dictionary, passes=20, random_state=42)
    
    perplexity = lda_model.log_perplexity(corpus)
    perplexities.append(perplexity)
    
    coherence_model = CoherenceModel(model=lda_model, texts=texts, dictionary=dictionary, coherence='c_v')
    coherence_score = coherence_model.get_coherence()
    coherences.append(coherence_score)

# Results
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(num_topics_range, perplexities, marker='o')
plt.title('Perplexity by Number of Topics')
plt.xlabel('Number of topics')
plt.ylabel('Perplexity')

plt.subplot(1, 2, 2)
plt.plot(num_topics_range, coherences, marker='o', color='orange')
plt.title('Coherence by Number of Topics')
plt.xlabel('Number of topics')
plt.ylabel('Coherence')

plt.tight_layout
plt.show()

# %% [markdown]
# ## Performing LDA for the optimal number of topics

# %%
# Apply LDA
num_topics = 3
lda_model = LdaModel(corpus, num_topics=num_topics, id2word=dictionary, passes=40, random_state=42)
generated_topics =[]

# Print topics
topics = lda_model.print_topics(num_words=10)
for topic in topics:
    print(topic)
    generated_topics.append(topic)

# Show visualization
vis = pyLDAvis.gensim_models.prepare(lda_model, corpus, dictionary)

pyLDAvis.display(vis)
# Out:
# (0, '0.009*"portfolio" + 0.008*"optimization" + 0.007*"problem" + 0.007*"propose" + 0.006*"learn" + 0.006*"model" + 0.005*"use" + 0.005*"base" + 0.005*"algorithm" + 0.005*"approach"')
# (1, '0.006*"portfolio" + 0.006*"management" + 0.006*"learn" + 0.005*"use" + 0.005*"research" + 0.004*"study" + 0.004*"approach" + 0.004*"base" + 0.003*"process" + 0.003*"provide"')
# (2, '0.009*"model" + 0.009*"learn" + 0.008*"return" + 0.007*"market" + 0.007*"use" + 0.007*"asset" + 0.007*"portfolio" + 0.006*"stock" + 0.006*"risk" + 0.006*"base"')
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el46952132914337449792671139" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el46952132914337449792671139_data = {"mdsDat": {"x": [-0.06242973192719209, -0.033167306416087686, 0.09559703834327976], "y": [0.06091776484648022, -0.07476167139882894, 0.013843906552348736], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [65.12859796257041, 20.46439355825871, 14.407008479170882]}, "tinfo": {"Term": ["problem", "portfolio", "management", "optimization", "research", "solve", "approach", "function", "propose", "application", "solution", "optimal", "algorithm", "use", "constraint", "process", "case", "learn", "study", "framework", "new", "design", "challenge", "identify", "develop", "control", "numerical", "decision", "article", "make", "memory", "lstm", "exchange", "predictability", "forecasting", "extract", "macroeconomic", "monthly", "movement", "predictor", "recurrent", "v", "momentum", "news", "january", "convolutional", "square", "french", "fluctuation", "robustness", "cryptocurrencies", "fama", "forest", "c", "bond", "month", "pricing", "volatility", "heterogeneous", "bayesian", "short", "predict", "predictive", "stock", "return", "forecast", "index", "price", "elsevier", "investor", "long", "prediction", "asset", "feature", "ratio", "market", "significantly", "empirical", "b", "sample", "historical", "model", "risk", "machine", "high", "learn", "financial", "show", "result", "use", "factor", "investment", "data", "performance", "base", "time", "method", "portfolio", "study", "propose", "strategy", "paper", "network", "approach", "term", "convex", "bound", "computationally", "quadratic", "solver", "springer", "integer", "perturbation", "pareto", "deploy", "multiplier", "formula", "quickly", "epsilon", "hjb", "speed", "bellman", "regret", "feedforward", "cardinality", "responsibility", "region", "theorem", "wasserstein", "multiperiod", "hamilton", "jacobi", "alternate", "neighborhood", "thanks", "formulation", "convergence", "th", "solve", "version", "approximation", "cvar", "constraint", "maximization", "guarantee", "equation", "unknown", "problem", "reward", "solution", "numerical", "control", "finite", "optimization", "stochastic", "function", "example", "optimal", "algorithm", "illustrate", "call", "propose", "portfolio", "case", "framework", "application", "new", "real", "set", "demonstrate", "objective", "approach", "develop", "paper", "learn", "model", "base", "use", "method", "decision", "mean", "result", "show", "data", "risk", "performance", "strategy", "organizational", "soft", "educator", "library", "hierarchy", "code", "com", "emerald", "publishing", "collaboration", "ecosystem", "ieee", "leadership", "culture", "interview", "synopsis", "storage", "afterward", "expertise", "notable", "physical", "sac", "sufficiently", "competency", "software", "pivotal", "execute", "graduate", "store", "master", "student", "project", "overview", "teach", "course", "implementation", "resource", "successful", "skill", "review", "strategic", "area", "originality", "organization", "manage", "management", "research", "practice", "discuss", "academic", "business", "development", "knowledge", "explore", "enhance", "methodology", "purpose", "design", "challenge", "process", "portfolio", "application", "study", "article", "approach", "case", "use", "learn", "identify", "provide", "level", "analysis", "make", "base", "also", "different", "data", "paper", "method", "result", "machine", "decision", "model", "propose"], "Freq": [220.0, 553.0, 242.0, 287.0, 172.0, 90.0, 307.0, 121.0, 377.0, 137.0, 95.0, 145.0, 225.0, 500.0, 62.0, 150.0, 91.0, 592.0, 314.0, 168.0, 163.0, 114.0, 127.0, 83.0, 150.0, 62.0, 56.0, 172.0, 111.0, 167.0, 57.77371097912202, 51.98270158693731, 58.49781380233502, 34.83893120417136, 47.021450602592715, 40.430991073484535, 32.90035364252131, 30.032274923873988, 30.95213707570062, 30.0005098260889, 31.871263686760013, 68.3994583436866, 28.99001935856579, 24.27137993914789, 25.195381645990135, 34.51142169929293, 24.237619188118362, 23.30185738179995, 22.343898209536942, 40.94002234654411, 21 ...

# %%
display(generated_topics)
# Out:
# [(0,
#   '0.009*"portfolio" + 0.008*"optimization" + 0.007*"problem" + 0.007*"propose" + 0.006*"learn" + 0.006*"model" + 0.005*"use" + 0.005*"base" + 0.005*"algorithm" + 0.005*"approach"'),
#  (1,
#   '0.006*"portfolio" + 0.006*"management" + 0.006*"learn" + 0.005*"use" + 0.005*"research" + 0.004*"study" + 0.004*"approach" + 0.004*"base" + 0.003*"process" + 0.003*"provide"'),
#  (2,
#   '0.009*"model" + 0.009*"learn" + 0.008*"return" + 0.007*"market" + 0.007*"use" + 0.007*"asset" + 0.007*"portfolio" + 0.006*"stock" + 0.006*"risk" + 0.006*"base"')]

# %%
from wordcloud import WordCloud

# Função para gerar a nuvem de palavras para cada tópico
def plot_word_cloud(lda_model, num_topics, num_words=200):
    for topic_id in range(num_topics):
        # Obtém as palavras e suas probabilidades para o tópico
        words_probs = lda_model.show_topic(topic_id, num_words)
        # Constrói uma string para a nuvem de palavras
        word_freq = {word: prob for word, prob in words_probs}
        # Gera a nuvem de palavras
        wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)
        
        # Plota a nuvem de palavras
        plt.figure(figsize=(10, 5))
        plt.imshow(wordcloud, interpolation='bilinear')
        plt.axis("off")
        # plt.title(f'Topic {topic_id}')
        plt.show()

# Chamando a função para exibir as nuvens de palavras de cada tópico
plot_word_cloud(lda_model, num_topics)

# %%
# Calculate document-topic probabilities using Gensim
doc_topic_probs = []

for doc_id, doc_bow in enumerate(corpus):
    # Get the topic distribution for the document
    doc_topics = lda_model.get_document_topics(doc_bow, minimum_probability=0)
    # Sort the topics by topic ID
    doc_topics = sorted(doc_topics, key=lambda x: x[0])
    # Extract probabilities
    topic_probs = [prob for topic_id, prob in doc_topics]
    doc_topic_probs.append(topic_probs)

    # Print the probabilities for each document
    # print(f"\nDocument {doc_id}:")
    # for topic_id, prob in doc_topics:
    #     print(f"  Topic {topic_id}: {prob:.4f}")

# Convert the list of probabilities to a DataFrame
import pandas as pd

doc_topic_df = pd.DataFrame(doc_topic_probs)
doc_topic_df.columns = [f"Topic {i}" for i in range(num_topics)]
doc_topic_df.index = [f"Doc {i}" for i in range(len(doc_topic_df))]

# Display the first few rows of the DataFrame
print("\nDocument-Topic Probabilities:")
display(doc_topic_df)

# doc_topic_df.to_csv('doc_topic_probs.csv', index=False)
# Out:
# Document-Topic Probabilities:
#           Topic 0   Topic 1   Topic 2
# Doc 0    0.004892  0.696820  0.298288
# Doc 1    0.002490  0.852368  0.145142
# Doc 2    0.335019  0.298906  0.366075
# Doc 3    0.007332  0.984913  0.007755
# Doc 4    0.004808  0.113098  0.882094
# ...           ...       ...       ...
# Doc 896  0.004126  0.991437  0.004438
# Doc 897  0.032217  0.009575  0.958208
# Doc 898  0.003437  0.319075  0.677488
# Doc 899  0.992665  0.003483  0.003852
# Doc 900  0.355682  0.005025  0.639293
#
# [901 rows x 3 columns]

# %%
# Calculate document-topic probabilities using Gensim
doc_topic_probs = []

for doc_id, doc_bow in enumerate(corpus):
    # Get the topic distribution for the document
    doc_topics = lda_model.get_document_topics(doc_bow, minimum_probability=0)
    # Sort the topics by topic ID
    doc_topics = sorted(doc_topics, key=lambda x: x[0])
    # Extract probabilities
    topic_probs = [prob for topic_id, prob in doc_topics]
    doc_topic_probs.append(topic_probs)

# Conversão da lista de probabilidades em um DataFrame
doc_topic_df = pd.DataFrame(doc_topic_probs)
doc_topic_df.columns = [f"Topic {i}" for i in range(num_topics)]

# Extração de informações adicionais dos documentos
# doc_ids = [getattr(doc, 'id', None) for doc in docs]
doc_titles = [getattr(doc, 'title', '') for doc in docs_orig]
doc_abstracts = [getattr(doc, 'abstract', '') for doc in docs_orig]
doc_authors = [[getattr(author, 'name', '') for author in getattr(doc, 'authors', [])] for doc in docs_orig]
doc_citcount = [getattr(doc, 'citation_count', '') for doc in docs_orig]
doc_year = [getattr(doc, 'publication_year', '') for doc in docs_orig]

# Adição das informações ao DataFrame
# doc_topic_df['ID'] = doc_ids
doc_topic_df['Title'] = doc_titles
doc_topic_df['Abstract'] = doc_abstracts
doc_topic_df['Authors'] = doc_authors
doc_topic_df['Citation Count'] = doc_citcount
doc_topic_df['Year'] = doc_year

# Reorganização das colunas para melhor visualização
cols = ['Title', 'Abstract', 'Authors', 'Citation Count', 'Year'] + [f"Topic {i}" for i in range(num_topics)]
doc_topic_df = doc_topic_df[cols]

# Filtro dos tópicos
topic0 = doc_topic_df[doc_topic_df['Topic 0'] >= 0.7]
citcount = topic0[topic0['Citation Count'] >= 10].sort_values(by='Citation Count', ascending=False)

display(len(citcount))
display(citcount)
citcount.to_clipboard()
# citcount.to_csv('citcount_topic0.csv', sep=";",index=False)
# Out:
# 30
#                                                  Title  \
# 772                     Smart "Predict, then Optimize"
# 522  Machine Learning Approximation Algorithms for ...
# 246                                       Deep hedging
# 557  Minimax and Biobjective Portfolio Selection Ba...
# 388  Fuzzy portfolio selection based on three-way d...
# 120  Applications of artificial intelligence in bus...
# 430  IMPACT OF MACHINE learning ON Management, heal...
# 115  A parallel variable neighborhood search algori...
# 669  Portfolio optimization of energy communities t...
# 60   A Modern Approach towards an Industry 4.0 Mode...
# 299  Dynamic Replication and Hedging: A Reinforceme...
# 203  Classical versus quantum models in machine lea...
# 717  Recent advances in reinforcement learning in f...
# 777  Squirrel search algorithm for portfolio optimi...
# 224  Continuous-time reinforcement learning approac...
# 609  Online Mixed-Integer Optimization in Milliseconds
# 840  The Nexus between Formal Credit and E-Commerce...
# 438  Improving Generalization in Reinforcement Lear...
# 606  Observer and control design in partially obser...
# 81   An Evaluation of the Environmental Payback Tim...
# 13   A Consortium Blockchain-Based Secure and Trust...
# 85   A New Data-Driven Distributionally Robust Port...
# 751           Robust Risk-Aware Reinforcement Learning
# 184  Bilateral negotiations for electricity market ...
# 44   A hybrid combinatorial approach to a two-stage...
# 628  Optimizing a portfolio of mean-reverting asset...
# 257  Deep-Learning Solution to Portfolio Selection ...
# 241          Deep deterministic portfolio optimization
# 31   Adversarial Attacks Against Reinforcement Lear...
# 198  Cardinality Constrained Portfolio Optimization...
#
#                                               Abstract  \
# 772  Many real-world analytics problems involve two...
# 522  High-dimensional partial differential equation...
# 246  We present a framework for hedging a portfolio...
# 557  Portfolio selection is one of the important is...
# 388  The goal of fuzzy portfolio selection is to ma...
# 120  In the e-commerce and financial industries, AI...
# 430  In the agriculture and healthcare industries, ...
# 115  Over the years, portfolio optimization remains...
# 669  Cities are expected to grow further, and energ...
# 60   Every so often, a confluence of novel technolo...
# 299  The authors of this article address the proble...
# 203  Although several models have been proposed tow...
# 717  The rapid changes in the finance industry due ...
# 777  Portfolio Optimization is a standard financial...
# 224  This paper considers the problem of policy opt...
# 609  We propose a method to approximate the solutio...
# 840  E-commerce furnishes farmers in rural China wi...
# 438  With the increasing sophistication of artifici...
# 606  The controllable Partially Observable Markov D...
# 81   The majority of Italian schools (70%) were bui...
# 13   In recent times, electronic portfolios (e-port...
# 85   Since optimal portfolio strategy depends heavi...
# 751  We present a reinforcement learning (RL) appro...
# 184  Bilateral transactions hedge both sides agains...
# 44   Portfolio optimization is one of the most impo...
# 628  Optimizing a portfolio of mean-reverting asset...
# 257  This paper investigates a deep-learning soluti...
# 241  Can deep reinforcement learning algorithms be ...
# 31   Many researchers have incorporated deep neural...
# 198  Inspired by sparse learning, the Markowitz mea...
#
#                                                Authors  Citation Count  Year  \
# 772                     [Elmachtoub, A.N., Grigas, P.]             248  2022
# 522                [Beck, C., Weinan, E., Jentzen, A.]             175  2019
# 246  [Buehler, H., Gonon, L., Teichmann, J., Wood, B.]             160  2019
# 557                            [Leung, M.F., Wang, J.]              93  2021
# 388  [Wang, X.H., Wang, B., Liu, S., Li, H.X., Wang...              82  2022
# 120  [Pallathadka H., Ramirez-Asis E.H., Loli-Poma ...              79  2023
# 430  [Pallathadka H., Mustafa M., Sanchez D.T., Sek...              78  2023
# 115               [Akbay M.A., Kalayci C.B., Polat O.]              58  2020
# 669  [Fleischhacker, A., Lettner, G., Schwabeneder,...              56  2019
# 60   [Tsaramirsis, G., Kantaros, A., Al-Darraji, I....              55  2022
# 299                             [Kolm P.N., Ritter G.]              46  2019
# 203  [Alcazar, J., Leyton-Ortega, V., Perdomo-Ortiz...              37  2020
# 717                 [Hambly, B., Xu, R.Y., Yang, H.N.]              36  2023
# 777                            [Dhaini M., Mansour N.]              31  2021
# 224  [Garcia-Galicia, M., Carsteanu, A.A., Clempner...              28  2019
# 609                      [Bertsimas, D., Stellato, B.]              24  2022
# 840  [Yang, S.X., Wang, H.L., Wang, Z.X., Koondhar,...              19  2021
# 438    [Kuo, C.H., Chen, C.T., Lin, S.J., Huang, S.H.]              18  2021
# 606                    [Clempner, J.B., Poznyak, A.S.]              15  2019
# 81   [Asdrubali, F., Venanzi, D., Evangelisti, L., ...              15  2021
# 13    [Merlec, M.M., Islam, M.M., Lee, Y.K., In, H.P.]              15  2022
# 85                      [Du, N.N., Liu, Y.K., Liu, Y.]              14  2021
# 751  [Jaimungal, S., Pesenti, S.M., Wang, Y.S., Tat...              14  2022
# 184  [Imran, K., Zhang, J.F., Pal, A., Khattak, A.,...              13  2020
# 44   [Cui, T.X., Bai, R.B., Ding, S.S., Parkes, A.J...              13  2020
# 628      [Mulvey, J.M., Sun, Y.F., Wang, M.D., Ye, J.]              12  2020
# 257                          [Tsang, K.H., Wong, H.Y.]              11  2020
# 241  [Chaouki A., Hardiman S., Schmidt C., Serie E....              11  2020
# 31   [Chen, Y.Y., Chen, C.T., Sang, C.Y., Yang, Y.C...              10  2021
# 198       [Shi, Z.L., Li, X.P., Leung, C.S., So, H.C.]              10  2024
#
#       Topic 0   Topic 1   Topic 2
# 772  0.853515  0.003905  0.142579
# 522  0.952955  0.003564  0.043482
# 246  0.986140  0.004304  0.009556
# 557  0.722508  0.006829  0.270663
# 388  0.795602  0.004962  0.199436
# 120  0.989711  0.005174  0.005116
# 430  0.990841  0.004488  0.004671
# 115  0.761626  0.003646  0.234728
# 669  0.833814  0.004971  0.161215
# 60   0.991584  0.004400  0.004016
# 299  0.819536  0.006701  0.173763
# 203  0.888143  0.003499  0.108357
# 717  0.991499  0.004394  0.004106
# 777  0.861168  0.004322  0.134510
# 224  0.891043  0.003027  0.105930
# 609  0.993016  0.003435  0.003548
# 840  0.727059  0.086931  0.186011
# 438  0.809882  0.004399  0.185720
# 606  0.770441  0.003662  0.225897
# 81   0.992626  0.003614  0.003760
# 13   0.992979  0.003710  0.003310
# 85   0.990429  0.004392  0.005179
# 751  0.989357  0.005085  0.005558
# 184  0.764364  0.004471  0.231165
# 44   0.817253  0.003665  0.179082
# 628  0.985628  0.006614  0.007758
# 257  0.878262  0.004707  0.117031
# 241  0.977112  0.010291  0.012596
# 31   0.955364  0.003984  0.040652
# 198  0.988444  0.005642  0.005914

# %%
topic0 = doc_topic_df[doc_topic_df['Topic 0'] >= 0.7]
citcount0 = topic0[topic0['Citation Count'] >= 10].sort_values(by='Citation Count', ascending=False)

display(len(citcount0))
display(citcount0)
citcount0.to_clipboard()
# Out:
# 30
#                                                  Title  \
# 772                     Smart "Predict, then Optimize"
# 522  Machine Learning Approximation Algorithms for ...
# 246                                       Deep hedging
# 557  Minimax and Biobjective Portfolio Selection Ba...
# 388  Fuzzy portfolio selection based on three-way d...
# 120  Applications of artificial intelligence in bus...
# 430  IMPACT OF MACHINE learning ON Management, heal...
# 115  A parallel variable neighborhood search algori...
# 669  Portfolio optimization of energy communities t...
# 60   A Modern Approach towards an Industry 4.0 Mode...
# 299  Dynamic Replication and Hedging: A Reinforceme...
# 203  Classical versus quantum models in machine lea...
# 717  Recent advances in reinforcement learning in f...
# 777  Squirrel search algorithm for portfolio optimi...
# 224  Continuous-time reinforcement learning approac...
# 609  Online Mixed-Integer Optimization in Milliseconds
# 840  The Nexus between Formal Credit and E-Commerce...
# 438  Improving Generalization in Reinforcement Lear...
# 606  Observer and control design in partially obser...
# 81   An Evaluation of the Environmental Payback Tim...
# 13   A Consortium Blockchain-Based Secure and Trust...
# 85   A New Data-Driven Distributionally Robust Port...
# 751           Robust Risk-Aware Reinforcement Learning
# 184  Bilateral negotiations for electricity market ...
# 44   A hybrid combinatorial approach to a two-stage...
# 628  Optimizing a portfolio of mean-reverting asset...
# 257  Deep-Learning Solution to Portfolio Selection ...
# 241          Deep deterministic portfolio optimization
# 31   Adversarial Attacks Against Reinforcement Lear...
# 198  Cardinality Constrained Portfolio Optimization...
#
#                                               Abstract  \
# 772  Many real-world analytics problems involve two...
# 522  High-dimensional partial differential equation...
# 246  We present a framework for hedging a portfolio...
# 557  Portfolio selection is one of the important is...
# 388  The goal of fuzzy portfolio selection is to ma...
# 120  In the e-commerce and financial industries, AI...
# 430  In the agriculture and healthcare industries, ...
# 115  Over the years, portfolio optimization remains...
# 669  Cities are expected to grow further, and energ...
# 60   Every so often, a confluence of novel technolo...
# 299  The authors of this article address the proble...
# 203  Although several models have been proposed tow...
# 717  The rapid changes in the finance industry due ...
# 777  Portfolio Optimization is a standard financial...
# 224  This paper considers the problem of policy opt...
# 609  We propose a method to approximate the solutio...
# 840  E-commerce furnishes farmers in rural China wi...
# 438  With the increasing sophistication of artifici...
# 606  The controllable Partially Observable Markov D...
# 81   The majority of Italian schools (70%) were bui...
# 13   In recent times, electronic portfolios (e-port...
# 85   Since optimal portfolio strategy depends heavi...
# 751  We present a reinforcement learning (RL) appro...
# 184  Bilateral transactions hedge both sides agains...
# 44   Portfolio optimization is one of the most impo...
# 628  Optimizing a portfolio of mean-reverting asset...
# 257  This paper investigates a deep-learning soluti...
# 241  Can deep reinforcement learning algorithms be ...
# 31   Many researchers have incorporated deep neural...
# 198  Inspired by sparse learning, the Markowitz mea...
#
#                                                Authors  Citation Count  Year  \
# 772                     [Elmachtoub, A.N., Grigas, P.]             248  2022
# 522                [Beck, C., Weinan, E., Jentzen, A.]             175  2019
# 246  [Buehler, H., Gonon, L., Teichmann, J., Wood, B.]             160  2019
# 557                            [Leung, M.F., Wang, J.]              93  2021
# 388  [Wang, X.H., Wang, B., Liu, S., Li, H.X., Wang...              82  2022
# 120  [Pallathadka H., Ramirez-Asis E.H., Loli-Poma ...              79  2023
# 430  [Pallathadka H., Mustafa M., Sanchez D.T., Sek...              78  2023
# 115               [Akbay M.A., Kalayci C.B., Polat O.]              58  2020
# 669  [Fleischhacker, A., Lettner, G., Schwabeneder,...              56  2019
# 60   [Tsaramirsis, G., Kantaros, A., Al-Darraji, I....              55  2022
# 299                             [Kolm P.N., Ritter G.]              46  2019
# 203  [Alcazar, J., Leyton-Ortega, V., Perdomo-Ortiz...              37  2020
# 717                 [Hambly, B., Xu, R.Y., Yang, H.N.]              36  2023
# 777                            [Dhaini M., Mansour N.]              31  2021
# 224  [Garcia-Galicia, M., Carsteanu, A.A., Clempner...              28  2019
# 609                      [Bertsimas, D., Stellato, B.]              24  2022
# 840  [Yang, S.X., Wang, H.L., Wang, Z.X., Koondhar,...              19  2021
# 438    [Kuo, C.H., Chen, C.T., Lin, S.J., Huang, S.H.]              18  2021
# 606                    [Clempner, J.B., Poznyak, A.S.]              15  2019
# 81   [Asdrubali, F., Venanzi, D., Evangelisti, L., ...              15  2021
# 13    [Merlec, M.M., Islam, M.M., Lee, Y.K., In, H.P.]              15  2022
# 85                      [Du, N.N., Liu, Y.K., Liu, Y.]              14  2021
# 751  [Jaimungal, S., Pesenti, S.M., Wang, Y.S., Tat...              14  2022
# 184  [Imran, K., Zhang, J.F., Pal, A., Khattak, A.,...              13  2020
# 44   [Cui, T.X., Bai, R.B., Ding, S.S., Parkes, A.J...              13  2020
# 628      [Mulvey, J.M., Sun, Y.F., Wang, M.D., Ye, J.]              12  2020
# 257                          [Tsang, K.H., Wong, H.Y.]              11  2020
# 241  [Chaouki A., Hardiman S., Schmidt C., Serie E....              11  2020
# 31   [Chen, Y.Y., Chen, C.T., Sang, C.Y., Yang, Y.C...              10  2021
# 198       [Shi, Z.L., Li, X.P., Leung, C.S., So, H.C.]              10  2024
#
#       Topic 0   Topic 1   Topic 2
# 772  0.853515  0.003905  0.142579
# 522  0.952955  0.003564  0.043482
# 246  0.986140  0.004304  0.009556
# 557  0.722508  0.006829  0.270663
# 388  0.795602  0.004962  0.199436
# 120  0.989711  0.005174  0.005116
# 430  0.990841  0.004488  0.004671
# 115  0.761626  0.003646  0.234728
# 669  0.833814  0.004971  0.161215
# 60   0.991584  0.004400  0.004016
# 299  0.819536  0.006701  0.173763
# 203  0.888143  0.003499  0.108357
# 717  0.991499  0.004394  0.004106
# 777  0.861168  0.004322  0.134510
# 224  0.891043  0.003027  0.105930
# 609  0.993016  0.003435  0.003548
# 840  0.727059  0.086931  0.186011
# 438  0.809882  0.004399  0.185720
# 606  0.770441  0.003662  0.225897
# 81   0.992626  0.003614  0.003760
# 13   0.992979  0.003710  0.003310
# 85   0.990429  0.004392  0.005179
# 751  0.989357  0.005085  0.005558
# 184  0.764364  0.004471  0.231165
# 44   0.817253  0.003665  0.179082
# 628  0.985628  0.006614  0.007758
# 257  0.878262  0.004707  0.117031
# 241  0.977112  0.010291  0.012596
# 31   0.955364  0.003984  0.040652
# 198  0.988444  0.005642  0.005914

# %%
topic1 = doc_topic_df[doc_topic_df['Topic 1'] >= 0.7]
citcount1 = topic1[topic1['Citation Count'] >= 10].sort_values(by='Citation Count', ascending=False)

display(len(citcount1))
display(citcount1)
citcount1.to_clipboard()
# Out:
# 15
#                                                  Title  \
# 132  Artificial intelligence and machine learning i...
# 705  Project Lineage Management and Project Portfol...
# 362  Finding true north: Design and implementation ...
# 707  Project Portfolio Management teaching: Contrib...
# 121  Applications of Explainable Artificial Intelli...
# 46   AI and Machine Learning in Real Estate Investment
# 577  Multi-project management in inter-organization...
# 337  Evolution of research in finance over the last...
# 142  Assessment of stored red blood cells through l...
# 762  Shaping the event portfolio management field: ...
# 163        A survey of machine learning in credit risk
# 763  Shared Leadership for Learning in Denver's Por...
# 395  Goals and benefits of digital transformation p...
# 33         A framework for online investment decisions
# 49   AI Research Funding Portfolios and Extreme Growth
#
#                                               Abstract  \
# 132  This study reviewed the artificial intelligenc...
# 705  Project portfolio approaches consider various ...
# 362  This study investigates the evolution of the d...
# 707  Project Portfolio Management (PPM) is becoming...
# 121  Digitalization and technologization affect num...
# 46   The topic of artificial intelligence (AI) is s...
# 577  Multi-project management is typically consider...
# 337  A standard literature review focuses on the hi...
# 142  Transfusion of red blood cells (RBCs) is one o...
# 762  Purpose - This paper aims to examine how vario...
# 163  Machine learning algorithms have come to domin...
# 763  Purpose: This study examines how district gove...
# 395  Background: Digital transformation (DT) is an ...
# 33   The artificial segmentation of the investment ...
# 49   Our work analyzes the artificial intelligence ...
#
#                                                Authors  Citation Count  Year  \
# 132  [Ahmed S., Alshater M.M., Ammari A.E., Hammami...             130  2022
# 705                           [Kock A., Gemunden H.G.]              44  2019
# 362  [Formentini, M., Ellram, L.M., Boem, M., Da Re...              27  2019
# 707                   [Barbosa, M.W., Rodrigues, C.D.]              27  2020
# 121                  [Weber, P., Carl, K.V., Hinz, O.]              24  2024
# 46                                     [Viriato, J.C.]              20  2019
# 577                         [Martinsuo, M., Ahola, T.]              20  2022
# 337            [Alhenawi, Y., Hassan, M.K., Hasan, R.]              16  2022
# 142  [Isiksacan, Z., D'Alessandro, A., Wolf, S.M., ...              15  2023
# 762                             [Ziakas, V., Getz, D.]              15  2020
# 163                                    [Breeden, J.L.]              13  2021
# 763               [Torres, A.C., Bulkley, K., Kim, T.]              12  2020
# 395     [Gertzen, W.M., Van der Lingen, E., Steyn, H.]              11  2022
# 33   [Paskaramoorthy, A.B., Gebbie, T.J., van Zyl, ...              10  2020
# 49   [Rahkovsky I., Toney A., Boyack K.W., Klavans ...              10  2021
#
#       Topic 0   Topic 1   Topic 2
# 132  0.004390  0.714997  0.280612
# 705  0.006464  0.986895  0.006640
# 362  0.003827  0.992449  0.003724
# 707  0.004848  0.990296  0.004856
# 121  0.004425  0.952502  0.043072
# 46   0.004873  0.989809  0.005318
# 577  0.005825  0.988367  0.005808
# 337  0.003430  0.981295  0.015275
# 142  0.004648  0.990127  0.005225
# 762  0.003185  0.993511  0.003304
# 163  0.006546  0.720912  0.272542
# 763  0.004357  0.891981  0.103662
# 395  0.003414  0.992913  0.003673
# 33   0.131410  0.863369  0.005222
# 49   0.003573  0.992662  0.003764

# %%
topic2 = doc_topic_df[doc_topic_df['Topic 2'] >= 0.8]
citcount2 = topic2[topic2['Citation Count'] >= 15].sort_values(by='Citation Count', ascending=False)

display(len(citcount2))
display(citcount2)
citcount2.to_clipboard()
# Out:
# 73
#                                                  Title  \
# 313       Empirical Asset Pricing via Machine Learning
# 533       Machine learning in the Chinese stock market
# 550  Mean-variance portfolio optimization using mac...
# 237  Decision-making for financial trading: A fusio...
# 170                   Autoencoder asset pricing models
# ..                                                 ...
# 108  A novel prediction based portfolio optimizatio...
# 546  Markowitz Mean-Variance Portfolio Optimization...
# 586  Neural network embeddings on corporate annual ...
# 497  Learning from the Joneses: Technology spillove...
# 286    Does Smooth Ambiguity Matter for Asset Pricing?
#
#                                               Abstract  \
# 313  We perform a comparative analysis of machine l...
# 533  We add to the emerging literature on empirical...
# 550  The success of portfolio construction depends ...
# 237  Forecasting stock returns is an exacting prosp...
# 170  We propose a new latent factor conditional ass...
# ..                                                 ...
# 108  Portfolio optimization is an important part of...
# 546  With the advances in time-series prediction, s...
# 586  In recent years, there has been an increased i...
# 497  This paper provides empirical evidence for the...
# 286  We use the Bayesian method introduced by Galla...
#
#                                                Authors  Citation Count  Year  \
# 313                   [Gu, S.H., Kelly, B., Xiu, D.C.]             715  2020
# 533               [Leippold, M., Wang, Q., Zhou, W.Y.]             158  2022
# 550  [Chen, W., Zhang, H.Y., Mehlawat, M.K., Jia, L...             144  2021
# 237  [Paiva, F.D., Cardoso, R.T.N., Hanaoka, G.P., ...             139  2019
# 170                   [Gu, S.H., Kelly, B., Xiu, D.C.]             131  2021
# ..                                                 ...             ...   ...
# 108                   [Ma, Y.L., Wang, W.Z., Ma, Q.T.]              16  2023
# 546                  [Chaweewanchon, A., Chaysiri, R.]              16  2022
# 586      [Adosoglou, G., Lombardo, G., Pardalos, P.M.]              15  2021
# 497                                        [Tseng, K.]              15  2022
# 286     [Gallant, A.R., Jahan-Parvar, M.R., Liu, H.N.]              15  2019
#
#       Topic 0   Topic 1   Topic 2
# 313  0.007622  0.007228  0.985150
# 533  0.005446  0.005772  0.988782
# 550  0.004319  0.004157  0.991524
# 237  0.034114  0.127269  0.838617
# 170  0.005581  0.005500  0.988919
# ..        ...       ...       ...
# 108  0.004886  0.004501  0.990613
# 546  0.004300  0.004107  0.991593
# 586  0.003075  0.003184  0.993741
# 497  0.004269  0.004559  0.991173
# 286  0.009380  0.008473  0.982147
#
# [73 rows x 8 columns]

# %%
litstudy.plot_year_histogram(docs_orig, vertical=True)
# Out:
# <Axes: title={'center': 'Year of publications'}, ylabel='No. of documents'>
